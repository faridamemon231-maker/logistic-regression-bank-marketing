# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/bank-additional-full.csv',sep=";")
df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %%
df.shape
# Out:
# (41188, 21)

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(12)

# %%
df.drop_duplicates(inplace=True)

# %%
for i in df.columns:
  if df[i].dtype != 'object':
    sns.boxplot(df[i])
    plt.xlabel(i)
    plt.show()

# %%
q1 = df['age'].quantile(0.25)
q3 = df['age'].quantile(0.75)
iqr = q3-q1
lb = q1-1.5*iqr
ub= q3+1.5*iqr
df = df[(df['age']>=lb)&(df['age']<=ub)]

# %%
df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41181   37       admin.  married    university.degree       no     yes   no
# 41182   29   unemployed   single             basic.4y       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40708 entries, 0 to 41186
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             40708 non-null  int64
#  1   job             40708 non-null  object
#  2   marital         40708 non-null  object
#  3   education       40708 non-null  object
#  4   default         40708 non-null  object
#  5   housing         40708 non-null  object
#  6   loan            40708 non-null  object
#  7   contact         40708 non-null  object
#  8   month           40708 non-null  object
#  9   day_of_week     40708 non-null  object
#  10  duration        40708 non-null  int64
#  11  campaign        40708 non-null  int64
#  12  pdays           40708 non-null  int64
#  13  previous        40708 non-null  int64
#  14  poutcome        40708 non-null  object
#  15  emp.var.rate    40708 non-null  float64
#  16  cons.price.idx  40708 non-null  float64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for col in df.columns:
  if df[col].dtypes == "object":
    df[col] = le.fit_transform(df[col])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40708 entries, 0 to 41186
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   job             40708 non-null  int64
#  1   marital         40708 non-null  int64
#  2   education       40708 non-null  int64
#  3   default         40708 non-null  int64
#  4   housing         40708 non-null  int64
#  5   loan            40708 non-null  int64
#  6   contact         40708 non-null  int64
#  7   month           40708 non-null  int64
#  8   day_of_week     40708 non-null  int64
#  9   duration        40708 non-null  int64
#  10  campaign        40708 non-null  int64
#  11  previous        40708 non-null  int64
#  12  poutcome        40708 non-null  int64
#  13  emp.var.rate    40708 non-null  float64
#  14  cons.price.idx  40708 non-null  float64
#  15  cons.conf.idx   40708 non-null  float64
#  16  euribor3m       40708 non-null  float64
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
col_list = []
for i in df.columns:
  if ((df[i].dtype != 'object')&(i!='y')):
    col_list.append(i) #object avgr ne and target column sivay ne column ne empty column list ma store kru
x=df[col_list] #ene x varible ma lethe
vif_data =pd.DataFrame()
vif_data['column_name'] = x.columns #data ne bthi column
vif_data['VIF_Score']=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))] #e bthi column ne multicolanirty check thse ana prthi

# %%
vif_data
# Out:
#       column_name  VIF_Score
# 0             job   2.075142
# 1         marital   4.742030
# 2       education   4.185333
# 3         default   1.363297
# 4         housing   2.183589
# 5            loan   1.206788
# 6         contact   2.233053
# 7           month   5.279346
# 8     day_of_week   2.991712
# 9        duration   1.982647
# 10       campaign   1.916334
# 11       previous   1.369846
# 12   emp.var.rate   1.559152
# 13  cons.conf.idx  14.870959

# %%
col_list = []
for i in df.columns:
  if ((df[i].dtype != 'object')&(i!='y')):
    col_list.append(i)
x=df[col_list]
vif_data =pd.DataFrame()
vif_data['column_name'] = x.columns #data ne bthi column
vif_data['VIF_Score']=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]

# %%
vif_data
# Out:
#      column_name  VIF_Score
# 0            job   2.025672
# 1        marital   4.015588
# 2      education   3.677447
# 3        default   1.306457
# 4        housing   2.057718
# 5           loan   1.196779
# 6        contact   2.231946
# 7          month   4.429220
# 8    day_of_week   2.752649
# 9       duration   1.878750
# 10      campaign   1.794272
# 11      previous   1.367022
# 12  emp.var.rate   1.558846

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
x
# Out:
#        job  marital  education  default  housing  loan  contact  month  \
# 0        3        1          0        0        0     0        1      6
# 1        7        1          3        1        0     0        1      6
# 2        7        1          3        0        2     0        1      6
# 3        0        1          1        0        0     0        1      6
# 4        7        1          3        0        0     2        1      6
# ...    ...      ...        ...      ...      ...   ...      ...    ...
# 41181    0        1          6        0        2     0        0      7
# 41182   10        2          0        0        2     0        0      7
# 41184    1        1          5        0        0     0        0      7
# 41185    5        1          6        0        2     0        0      7
# 41186    9        1          5        0        0     0        0      7
#
#        day_of_week  duration  campaign  previous  emp.var.rate
# ...

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 41181    1
# 41182    0
# 41184    0
# 41185    0
# 41186    1
# Name: y, Length: 40708, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
from sklearn.feature_selection import RFE

# %%
rfe = RFE(model)

# %%
rfe.fit(x,y)
# Out:
# RFE(estimator=LogisticRegression())

# %%
rfe.support_ #which feature selected e true batavse je nai select e false batvse
# Out:
# array([False,  True,  True,  True, False, False,  True, False, False,
#        False, False,  True,  True])

# %%
select_indeces = [i for i,data in enumerate(rfe.support_) if data==True]

# %%
select_indeces
# Out:
# [1, 2, 3, 6, 11, 12]

# %%
column_name = x.columns
selected_columns = column_name[select_indeces]
selected_columns
# Out:
# Index(['marital', 'education', 'default', 'contact', 'previous',
#        'emp.var.rate'],
#       dtype='object')

# %%
x= x.loc[:,['marital', 'education', 'default', 'contact', 'previous',
       'emp.var.rate']]

# %%
x
# Out:
#        marital  education  default  contact  previous  emp.var.rate
# 0            1          0        0        1         0           1.1
# 1            1          3        1        1         0           1.1
# 2            1          3        0        1         0           1.1
# 3            1          1        0        1         0           1.1
# 4            1          3        0        1         0           1.1
# ...        ...        ...      ...      ...       ...           ...
# 41181        1          6        0        0         0          -1.1
# 41182        2          0        0        0         1          -1.1
# 41184        1          5        0        0         0          -1.1
# 41185        1          6        0        0         0          -1.1
# 41186        1          5        0        0         0          -1.1
#
# [40708 rows x 6 columns]

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 41181    1
# 41182    0
# 41184    0
# 41185    0
# 41186    1
# Name: y, Length: 40708, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
lr= LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(x_test)

# %%
new_df = pd.DataFrame()
new_df['Actual'] = y_test
new_df['Predicted'] = y_pred
new_df
# Out:
#        Actual  Predicted
# 5713        0          0
# 6947        0          0
# 29780       0          0
# 18706       0          0
# 40891       1          0
# ...       ...        ...
# 20397       0          0
# 33468       1          0
# 35012       0          0
# 34270       0          0
# 34332       0          0
#
# [8142 rows x 2 columns]

# %%
from sklearn.metrics import*

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8919184475558831
